# %%
import numpy as np
import pandas as pd

import bar_chart_race as bcr

# %%
# Data import
df = pd.read_csv("data/data.csv", index_col='date')

# %%
df.head()
# Out:
#             province1_pos  province1_dis  province2_pos  province2_dis  \
# date
# 28-01-2020              0              0              0              0
# 29-01-2020              0              0              0              0
# 30-01-2020              0              0              0              0
# 31-01-2020              0              0              0              0
# 01-02-2020              0              0              0              0
#
#             bagmati_province_pos  bagmati_province_dis  gandaki_province_pos  \
# date
# 28-01-2020                     1                     0                     0
# 29-01-2020                     1                     0                     0
# 30-01-2020                     1                     0                     0
# 31-01-2020                     1                     0                     0
# 01-02-2020                     1                     0                     0
#
# ...

# %%
# Calculating active cases of each province
df['Province 1'] = df['province1_pos'] - df['province1_dis']
df['Province 2'] = df['province2_pos'] - df['province5_dis']
df['Bagmati Province'] = df['bagmati_province_pos'] - df['bagmati_province_dis']
df['Gandaki Province'] = df['gandaki_province_pos'] - df['gandaki_province_dis']
df['Province 5'] = df['province5_pos'] - df['province5_dis']
df['Karnali Province'] = df['karnali_province_pos'] - df['karnali_province_dis']
df['Sudurpaschim Province'] = df['sudurpaschim_province_pos'] - df['sudurpaschim_province_dis']

# %%
# Selecting on the active cases column
df_active = df[["Province 1",
                 "Province 2",
                 "Bagmati Province",
                 "Gandaki Province",
                 "Province 5",
                 "Karnali Province",
                 "Sudurpaschim Province"]]
df_active.head()
# Out:
#             Province 1  Province 2  Bagmati Province  Gandaki Province  \
# date
# 28-01-2020           0           0                 1                 0
# 29-01-2020           0           0                 1                 0
# 30-01-2020           0           0                 1                 0
# 31-01-2020           0           0                 1                 0
# 01-02-2020           0           0                 1                 0
#
#             Province 5  Karnali Province  Sudurpaschim Province
# date
# 28-01-2020           0                 0                      0
# 29-01-2020           0                 0                      0
# 30-01-2020           0                 0                      0
# 31-01-2020           0                 0                      0
# 01-02-2020           0                 0                      0

# %%
# Plotting the graph

bcr.bar_chart_race(
    df=df_active,
    filename='visualization/covid_19_cases.mp4',
    orientation='h',
    sort='desc',
    n_bars=7,
    fixed_order=False,
    fixed_max=True,
    steps_per_period=10,
    interpolate_period=False,
    label_bars=True,
    bar_size=.95,
    period_label={'x': .99, 'y': .25, 'ha': 'right', 'va': 'center'},
    period_summary_func=lambda v, r: {'x': .99, 'y': .18,
                                      's': f'Total Active Cases: {v.nlargest(7).sum():,.0f}',
                                      'ha': 'right', 'size': 8, 'family': 'Courier New'},
    perpendicular_bar_func=None,
    period_length=500,
    figsize=(5, 3),
    dpi=144,
    cmap='dark12',
    title='COVID-19 Active Cases by Province',
    bar_label_size=7,
    tick_label_size=7,
    shared_fontdict={'family' : 'Helvetica', 'color' : '.1'},
    scale='linear',
    writer=None,
    fig=None,
    bar_kwargs={'alpha': .7},
    filter_column_colors=False)
